# %% [markdown]
# # y_0 = \theta_0 + epsilon [one parameter]

# %%
import torch
import torch.optim as optim
import torch.nn as nn

SR_beta = 0.1 ## choose beta


# Generate values for the observed (y) and the predicted values given by the linear regression
torch.manual_seed(0)
intercept = torch.ones(100, 1)  # intercept
theta_true = torch.tensor([1.0])  
y = intercept @ theta_true + 0.01 * torch.randn(100)

# Initialise parameters to be estimated
theta00 = torch.randn(1, requires_grad=True)

# Set up the optimiser
optimizer = optim.Adam([theta00], lr=0.1)

theta_history1 = []

for i in range(500):
    y_pred = intercept @ theta00 + 0.01 * torch.randn(100)

    loss = SR_eval(SR_beta, y.view(-1, 1), y_pred.view(-1, 1))  # Compute loss
    loss.backward()  # Backpropagation
    optimizer.step()  # Update parameters
    optimizer.zero_grad()  # Zero gradients
    with torch.no_grad():
        # Print optimisation step
        theta_history1.append(theta00.clone())
        
print(f"Estimated parameters Energy: {theta00.detach().numpy()}")
print(f"True parameters Energy: {theta_true.numpy()}")
# Out:
# Estimated parameters Energy: [1.2909653]
# True parameters Energy: [1.]

# %%
import torch
import torch.optim as optim
import torch.nn as nn

SR_beta = 0.5 ## choose beta


# Generate values for the observed (y) and the predicted values given by the linear regression
torch.manual_seed(0)
intercept = torch.ones(100, 1)  # intercept
theta_true = torch.tensor([1.0])  # Corrected to ensure it's 1-dimensional
y = intercept @ theta_true + 0.01 * torch.randn(100)

# Initialise parameters to be estimated
theta01 = torch.randn(1, requires_grad=True)

# Set up the optimiser
optimizer = optim.Adam([theta01], lr=0.1)
theta_history2 = []
# Training loop
for i in range(500):
    y_pred = intercept @ theta01 + 0.01 * torch.randn(100)

    loss = SR_eval(SR_beta, y.view(-1, 1), y_pred.view(-1, 1))  # Compute loss
    loss.backward()  # Backpropagation
    optimizer.step()  # Update parameters
    optimizer.zero_grad()  # Zero gradients
    with torch.no_grad():
        # Print optimisation step
        theta_history2.append(theta01.clone())
print(f"Estimated parameters Energy: {theta01.detach().numpy()}")
print(f"True parameters Energy: {theta_true.numpy()}")
# Out:
# Estimated parameters Energy: [1.0081015]
# True parameters Energy: [1.]

# %%
import torch
import torch.optim as optim
import torch.nn as nn

SR_beta = 1.0 ## choose beta


# Generate values for the observed (y) and the predicted values given by the linear regression
torch.manual_seed(0)
intercept = torch.ones(100, 1)  # intercept
theta_true = torch.tensor([1.0]) 
y = intercept @ theta_true + 0.01 * torch.randn(100)

# Initialise parameters to be estimated
theta02 = torch.randn(1, requires_grad=True)

# Set up the optimiser
optimizer = optim.Adam([theta02], lr=0.1)
theta_history3 = []
# Training loop
for i in range(500):
    y_pred = intercept @ theta02 + 0.01 * torch.randn(100)

    loss = SR_eval(SR_beta, y.view(-1, 1), y_pred.view(-1, 1))  # Compute loss
    loss.backward()  # Backpropagation
    optimizer.step()  # Update parameters
    optimizer.zero_grad()  # Zero gradients
    with torch.no_grad():
        # Print optimisation step
        theta_history3.append(theta02.clone())
print(f"Estimated parameters Energy: {theta02.detach().numpy()}")
print(f"True parameters Energy: {theta_true.numpy()}")
# Out:
# Estimated parameters Energy: [0.99928135]
# True parameters Energy: [1.]

# %%
import torch
import torch.optim as optim
import torch.nn as nn


SR_beta = 1.5 ## choose beta


# Generate values for the observed (y) and the predicted values given by the linear regression
torch.manual_seed(0)
intercept = torch.ones(100, 1)  # intercept
theta_true = torch.tensor([1.0])  
y = intercept @ theta_true + 0.01 * torch.randn(100)

# Initialise parameters to be estimated
theta03 = torch.randn(1, requires_grad=True)

# Set up the optimiser
optimizer = optim.Adam([theta03], lr=0.1)
theta_history4 = []
# Training loop
for i in range(500):
    y_pred = intercept @ theta03 + 0.01 * torch.randn(100)

    loss = SR_eval(SR_beta, y.view(-1, 1), y_pred.view(-1, 1))  # Compute loss
    loss.backward()  # Backpropagation
    optimizer.step()  # Update parameters
    optimizer.zero_grad()  # Zero gradients
    with torch.no_grad():
        # Print optimisation step
        theta_history4.append(theta03.clone())
print(f"Estimated parameters Energy: {theta03.detach().numpy()}")
print(f"True parameters Energy: {theta_true.numpy()}")
# Out:
# Estimated parameters Energy: [1.003304]
# True parameters Energy: [1.]

# %%
import torch
import torch.optim as optim
import torch.nn as nn

SR_beta = 1.9 ## choose beta


# Generate values for the observed (y) and the predicted values given by the linear regression
torch.manual_seed(0)
intercept = torch.ones(100, 1)  # intercept
theta_true = torch.tensor([1.0])  
y = intercept @ theta_true + 0.01 * torch.randn(100)

# Initialise parameters to be estimated
theta04 = torch.randn(1, requires_grad=True)

# Set up the optimiser
optimizer = optim.Adam([theta04], lr=0.1)
theta_history5 = []
# Training loop
for i in range(500):
    y_pred = intercept @ theta04 + 0.01 * torch.randn(100)

    loss = SR_eval(SR_beta, y.view(-1, 1), y_pred.view(-1, 1))  # Compute loss
    loss.backward()  # Backpropagation
    optimizer.step()  # Update parameters
    optimizer.zero_grad()  # Zero gradients
    with torch.no_grad():
        # Print optimisation step
        theta_history5.append(theta04.clone())   

print(f"Estimated parameters Energy: {theta04.detach().numpy()}")
print(f"True parameters Energy: {theta_true.numpy()}")
# Out:
# Estimated parameters Energy: [0.9993169]
# True parameters Energy: [1.]

# %% [markdown]
# ## Optimisation

# %%
import matplotlib.pyplot as plt

# Convert lists to tensors
theta_history_tensor1 = torch.stack(theta_history1)
theta_history_tensor2 = torch.stack(theta_history2)
theta_history_tensor3 = torch.stack(theta_history3)
theta_history_tensor4 = torch.stack(theta_history4)
theta_history_tensor5 = torch.stack(theta_history5)


# Create first plot for Theta 0
plt.figure()
plt.plot(theta_history_tensor1[:, 0].numpy(), label='Beta = 0.1')
plt.plot(theta_history_tensor2[:, 0].numpy(), label='Beta = 0.5')
plt.plot(theta_history_tensor3[:, 0].numpy(), label='Beta = 1.0')
plt.plot(theta_history_tensor4[:, 0].numpy(), label='Beta = 1.5')
plt.plot(theta_history_tensor5[:, 0].numpy(), label='Beta = 1.9')
plt.title('Theta 0 History')
plt.xlabel('Iteration')
plt.ylabel('Theta 0')
plt.legend()
plt.grid(True)


plt.tight_layout()
plt.show()

# %% [markdown]
# ## Grid Search

# %%
import torch
import numpy as np
import torch.nn as nn
import matplotlib.pyplot as plt

# Generate values for the observed (y) and the predicted values given by the linear regression
torch.manual_seed(0)
intercept = torch.ones(100, 1)  # Intercept
theta_true = torch.tensor([1.0])  # Coefficient for intercept
y = intercept @ theta_true + 0.01 * torch.randn(100)

# Create a range of theta values
theta_values = torch.linspace(-3, 3, 100)

# Compute energy scores for each theta value
energy_scores1 = []
energy_scores2 = []
energy_scores3 = []
energy_scores4 = []
energy_scores5 = []

for theta in theta_values:
    y_pred = intercept * theta + 0.01 * torch.randn(100) 
    energy_scores1.append(SR_eval(0.1, [y], [y_pred]))
    
    y_pred = intercept * theta + 0.01 * torch.randn(100) 
    energy_scores2.append(SR_eval(0.5, [y], [y_pred]))
    
    y_pred = intercept * theta + 0.01 * torch.randn(100)  
    energy_scores3.append(SR_eval(1.0, [y], [y_pred]))
    
    y_pred = intercept * theta + 0.01 * torch.randn(100) 
    energy_scores4.append(SR_eval(1.5, [y], [y_pred]))
    
    y_pred = intercept * theta + 0.01 * torch.randn(100)  
    energy_scores5.append(SR_eval(1.9, [y], [y_pred]))

# Create a single plot for all beta values
plt.figure(figsize=(10, 8))

plt.plot(theta_values.numpy(), energy_scores1, label='Beta = 0.1')
plt.plot(theta_values.numpy(), energy_scores2, label='Beta = 0.5')
plt.plot(theta_values.numpy(), energy_scores3, label='Beta = 1.0')
plt.plot(theta_values.numpy(), energy_scores4, label='Beta = 1.5')
plt.plot(theta_values.numpy(), energy_scores5, label='Beta = 1.9')

plt.xlabel('Theta')
plt.ylabel('Energy Score')
plt.title('Energy Score for Different Theta Values')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # y = \theta_0 + \theta_1 x_1 + epsilon [two parameters]

# %%
import torch
import torch.optim as optim
import torch.nn.functional as F


SR_beta = 0.1 ## choose beta


# Generate values for the observed (y) and the predicted values given by the linear regression
torch.manual_seed(0)
X = torch.randn(100, 1)
intercept = torch.ones(100, 1)  # intercept
X = torch.cat((intercept, X), dim=1) 
theta_true = torch.tensor([0.5, 1.0]) 
y = X @ theta_true + 0.01 * torch.randn(100)

# Initialise parameters to be estimated
theta10 = torch.randn(2, requires_grad=True)  

# Set up the optimiser
optimizer = optim.Adam([theta10], lr=0.1)
theta_history6 = []
# Training loop
for i in range(500):

    y_pred = X @ theta10 + 0.01 * torch.randn(100)

    loss = SR_eval(SR_beta, y.view(-1, 1), y_pred.view(-1, 1))  # Compute loss
    loss.backward()  # Backpropagation
    optimizer.step()  # Update parameters
    optimizer.zero_grad()  # Zero gradients
    with torch.no_grad():
        # Print optimisation step
        theta_history6.append(theta10.clone())    
print(f"Estimated parameters Energy: {theta10.detach().numpy()}")
print(f"True parameters Energy: {theta_true.numpy()}")
# Out:
# Estimated parameters Energy: [0.6911588 0.7409513]
# True parameters Energy: [0.5 1. ]

# %%
import torch
import torch.optim as optim
import torch.nn.functional as F

SR_beta = 0.5 ## choose beta


# Generate values for the observed (y) and the predicted values given by the linear regression
torch.manual_seed(0)
X = torch.randn(100, 1)
intercept = torch.ones(100, 1)  # intercept
X = torch.cat((intercept, X), dim=1)  
theta_true = torch.tensor([0.5, 1.0])  
y = X @ theta_true + 0.01 * torch.randn(100)

# Initialize parameters to be estimated
theta11 = torch.randn(2, requires_grad=True)  

# Set up the optimiser
optimizer = optim.Adam([theta11], lr=0.1)
theta_history7 = []
# Training loop
for i in range(500):

    y_pred = X @ theta11 + 0.01 * torch.randn(100)

    loss = SR_eval(SR_beta, y.view(-1, 1), y_pred.view(-1, 1))  # Compute loss
    loss.backward()  # Backpropagation
    optimizer.step()  # Update parameters
    optimizer.zero_grad()  # Zero gradients
    with torch.no_grad():
        # Print optimisation step
        theta_history7.append(theta11.clone())      
print(f"Estimated parameters Energy: {theta11.detach().numpy()}")
print(f"True parameters Energy: {theta_true.numpy()}")
# Out:
# Estimated parameters Energy: [0.48725623 1.0038241 ]
# True parameters Energy: [0.5 1. ]

# %%
import torch
import torch.optim as optim
import torch.nn.functional as F


SR_beta = 1 ## choose beta


# Generate values for the observed (y) and the predicted values given by the linear regression
torch.manual_seed(0)
X = torch.randn(100, 1)
intercept = torch.ones(100, 1)  # intercept
X = torch.cat((intercept, X), dim=1)  
theta_true = torch.tensor([0.5, 1.0])  
y = X @ theta_true + 0.01 * torch.randn(100)

# Initialise parameters to be estimated
theta12 = torch.randn(2, requires_grad=True)  # Two parameters: intercept and coefficient for x

# Set up the optimiser
optimizer = optim.Adam([theta12], lr=0.1)
theta_history8 = []
# Training loop
for i in range(500):

    y_pred = X @ theta12 + 0.01 * torch.randn(100)

    loss = SR_eval(SR_beta, y.view(-1, 1), y_pred.view(-1, 1))  # Compute loss
    loss.backward()  # Backpropagation
    optimizer.step()  # Update parameters
    optimizer.zero_grad()  # Zero gradients
    with torch.no_grad():
        # Print optimisation step
        theta_history8.append(theta12.clone())    
print(f"Estimated parameters Energy: {theta12.detach().numpy()}")
print(f"True parameters Energy: {theta_true.numpy()}")
# Out:
# Estimated parameters Energy: [0.50526994 0.99029934]
# True parameters Energy: [0.5 1. ]

# %%
import torch
import torch.optim as optim
import torch.nn.functional as F


SR_beta = 1.5 ## choose beta


# Generate values for the observed (y) and the predicted values given by the linear regression
torch.manual_seed(0)
X = torch.randn(100, 1)
intercept = torch.ones(100, 1)  # intercept
X = torch.cat((intercept, X), dim=1)  
theta_true = torch.tensor([0.5, 1.0])  
y = X @ theta_true + 0.01 * torch.randn(100)

# Initialise parameters to be estimated
theta13 = torch.randn(2, requires_grad=True) 

# Set up the optimiser
optimizer = optim.Adam([theta13], lr=0.1)
theta_history9 = []
# Training loop
for i in range(500):

    y_pred = X @ theta13 + 0.01 * torch.randn(100)

    loss = SR_eval(SR_beta, y.view(-1, 1), y_pred.view(-1, 1))  # Compute loss
    loss.backward()  # Backpropagation
    optimizer.step()  # Update parameters
    optimizer.zero_grad()  # Zero gradients
    with torch.no_grad():
        # Print optimisation step
        theta_history9.append(theta13.clone())    
print(f"Estimated parameters Energy: {theta13.detach().numpy()}")
print(f"True parameters Energy: {theta_true.numpy()}")
# Out:
# Estimated parameters Energy: [0.50103676 0.9992104 ]
# True parameters Energy: [0.5 1. ]

# %%
import torch
import torch.optim as optim
import torch.nn.functional as F



SR_beta = 1.9 ## choose beta


# Generate values for the observed (y) and the predicted values given by the linear regression
torch.manual_seed(0)
X = torch.randn(100, 1)
intercept = torch.ones(100, 1)  # intercept
X = torch.cat((intercept, X), dim=1)  
theta_true = torch.tensor([0.5, 1.0])  
y = X @ theta_true + 0.01 * torch.randn(100)

# Initialise parameters to be estimated
theta14 = torch.randn(2, requires_grad=True)  

# Set up the optimiser
optimizer = optim.Adam([theta14], lr=0.1)
theta_history10 = []
# Training loop
for i in range(500):

    y_pred = X @ theta14 + 0.01 * torch.randn(100)

    loss = SR_eval(SR_beta, y.view(-1, 1), y_pred.view(-1, 1))  # Compute loss
    loss.backward()  # Backpropagation
    optimizer.step()  # Update parameters
    optimizer.zero_grad()  # Zero gradients
    with torch.no_grad():
        # Print optimisation step
        theta_history10.append(theta14.clone())       
print(f"Estimated parameters Energy: {theta14.detach().numpy()}")
print(f"True parameters Energy: {theta_true.numpy()}")
# Out:
# Estimated parameters Energy: [0.5027995 0.9979698]
# True parameters Energy: [0.5 1. ]

# %% [markdown]
# ## Optimisation

# %%
import matplotlib.pyplot as plt

# Convert lists to tensors
theta_history_tensor6 = torch.stack(theta_history6)
theta_history_tensor7 = torch.stack(theta_history7)
theta_history_tensor8 = torch.stack(theta_history8)
theta_history_tensor9 = torch.stack(theta_history9)
theta_history_tensor10 = torch.stack(theta_history10)



# Create first plot for Theta 0
plt.figure()
plt.plot(theta_history_tensor6[:, 0].numpy(), label='Beta = 0.1')
plt.plot(theta_history_tensor7[:, 0].numpy(), label='Beta = 0.5')
plt.plot(theta_history_tensor8[:, 0].numpy(), label='Beta = 1.0')
plt.plot(theta_history_tensor9[:, 0].numpy(), label='Beta = 1.5')
plt.plot(theta_history_tensor10[:, 0].numpy(), label='Beta = 1.9')
plt.title('Theta 0 History')
plt.xlabel('Iteration')
plt.ylabel('Theta 0')
plt.legend()
plt.grid(True)

# Show the first plot
plt.tight_layout()
plt.show()

# Create second plot for Theta 1
plt.figure()
plt.plot(theta_history_tensor6[:, 1].numpy(), label='Beta = 0.1')
plt.plot(theta_history_tensor7[:, 1].numpy(), label='Beta = 0.5')
plt.plot(theta_history_tensor8[:, 1].numpy(), label='Beta = 1.0')
plt.plot(theta_history_tensor9[:, 1].numpy(), label='Beta = 1.5')
plt.plot(theta_history_tensor10[:, 1].numpy(), label='Beta = 1.9')
plt.title('Theta 1 History')
plt.xlabel('Iteration')
plt.ylabel('Theta 1')
plt.legend()
plt.grid(True)

# Show the second plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Grid Search

# %%
import torch
import numpy as np
import torch.nn as nn
import matplotlib.pyplot as plt


# Generate values for the observed (y) and the predicted values given by the linear regression
torch.manual_seed(0)
X = torch.randn(100, 1)
intercept = torch.ones(100, 1)  # intercept
X = torch.cat((intercept, X), dim=1)  
theta_true = torch.tensor([0.5, 1.0])  
y = X @ theta_true + 0.01 * torch.randn(100)

# Create a range of theta values
theta_values = torch.linspace(-3, 3, 100)

# Compute energy scores for each theta value for the first parameter
energy_scores_first_param = []
energy_scores_second_param = []
energy_scores_first_param1 = []
energy_scores_second_param1 = []
energy_scores_first_param2 = []
energy_scores_second_param2 = []
energy_scores_first_param3 = []
energy_scores_second_param3 = []
energy_scores_first_param4 = []
energy_scores_second_param4 = []

for theta in theta_values:
    y_pred_first_param = X @ torch.tensor([theta, theta_true[1]]).reshape(2, 1) + 0.01 * torch.randn(100, 1)
    y_pred_second_param = X @ torch.tensor([theta_true[0], theta]).reshape(2, 1) + 0.01 * torch.randn(100, 1)

    energy_scores_first_param.append(SR_eval(0.1, [y], [y_pred_first_param]))
    energy_scores_second_param.append(SR_eval(0.1, [y], [y_pred_second_param]))
    energy_scores_first_param1.append(SR_eval(0.5, [y], [y_pred_first_param]))
    energy_scores_second_param1.append(SR_eval(0.5, [y], [y_pred_second_param]))
    energy_scores_first_param2.append(SR_eval(1.0, [y], [y_pred_first_param]))
    energy_scores_second_param2.append(SR_eval(1.0, [y], [y_pred_second_param]))
    energy_scores_first_param3.append(SR_eval(1.5, [y], [y_pred_first_param]))
    energy_scores_second_param3.append(SR_eval(1.5, [y], [y_pred_second_param]))
    energy_scores_first_param4.append(SR_eval(1.9, [y], [y_pred_first_param]))
    energy_scores_second_param4.append(SR_eval(1.9, [y], [y_pred_second_param]))

# Create plots for each parameter
plt.figure(figsize=(10, 8))

plt.plot(theta_values.numpy(), energy_scores_first_param, label='First Parameter (Beta = 0.1)')
plt.plot(theta_values.numpy(), energy_scores_first_param1, label='First Parameter (Beta = 0.5)')
plt.plot(theta_values.numpy(), energy_scores_first_param2, label='First Parameter (Beta = 1.0)')
plt.plot(theta_values.numpy(), energy_scores_first_param3, label='First Parameter (Beta = 1.5)')
plt.plot(theta_values.numpy(), energy_scores_first_param4, label='First Parameter (Beta = 1.9)')


plt.xlabel('Theta 0')
plt.ylabel('Energy Score')
plt.title('Energy Score for Different Theta Values (First Parameter)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()


plt.figure(figsize=(10, 8))

plt.plot(theta_values.numpy(), energy_scores_second_param, label='Second Parameter (Beta = 0.1)')
plt.plot(theta_values.numpy(), energy_scores_second_param1, label='Second Parameter (Beta = 0.5)')
plt.plot(theta_values.numpy(), energy_scores_second_param2, label='Second Parameter (Beta = 1.0)')
plt.plot(theta_values.numpy(), energy_scores_second_param3, label='Second Parameter (Beta = 1.5)')
plt.plot(theta_values.numpy(), energy_scores_second_param4, label='Second Parameter (Beta = 1.9)')
plt.xlabel('Theta 1')
plt.ylabel('Energy Score')
plt.title('Energy Score for Different Theta Values (Second Parameter)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # y = \theta_0 + \theta_1 x_1 + \theta_2 x_2 + \epsilon [three parameters]

# %%
import torch
import torch.optim as optim
import torch.nn.functional as F

SR_beta = 0.1 ## choose beta


# Generate values for the observed (y) and the predicted values given by the linear regression
torch.manual_seed(0)
X = torch.randn(100, 2)
intercept = torch.ones(100, 1)  # intercept
X = torch.cat((intercept, X), dim=1)  
theta_true = torch.tensor([0.5, 1.0, 2.0])  
y = X @ theta_true + 0.01 * torch.randn(100)

# Initialize parameters to be estimated
theta20 = torch.randn(3, requires_grad=True)  

# Set up the optimiser
optimizer = optim.Adam([theta20], lr=0.1)
theta_history11 = []
# Training loop
for i in range(500):

    y_pred = X @ theta20 + 0.01 * torch.randn(100)

    loss = SR_eval(SR_beta, y.view(-1, 1), y_pred.view(-1, 1))  # Compute loss
    loss.backward()  # Backpropagation
    optimizer.step()  # Update parameters
    optimizer.zero_grad()  # Zero gradients
    with torch.no_grad():
        # Print optimisation step
        theta_history11.append(theta20.clone())        
print(f"Estimated parameters Energy: {theta20.detach().numpy()}")
print(f"True parameters Energy: {theta_true.numpy()}")
# Out:
# Estimated parameters Energy: [-0.08220071  0.7760416   2.1630154 ]
# True parameters Energy: [0.5 1.  2. ]

# %%
import torch
import torch.optim as optim
import torch.nn.functional as F


SR_beta = 0.5 ## choose beta


# Generate values for the observed (y) and the predicted values given by the linear regression
torch.manual_seed(0)
X = torch.randn(100, 2)
intercept = torch.ones(100, 1)  # intercept
X = torch.cat((intercept, X), dim=1)  
theta_true = torch.tensor([0.5, 1.0, 2.0]) 
y = X @ theta_true + 0.01 * torch.randn(100)

# Initialise parameters to be estimated
theta21 = torch.randn(3, requires_grad=True)  

# Set up the optimiser
optimizer = optim.Adam([theta21], lr=0.1)
theta_history12 = []
# Training loop
for i in range(500):

    y_pred = X @ theta21 + 0.01 * torch.randn(100)

    loss = SR_eval(SR_beta, y.view(-1, 1), y_pred.view(-1, 1))  # Compute loss
    loss.backward()  # Backpropagation
    optimizer.step()  # Update parameters
    optimizer.zero_grad()  # Zero gradients
    with torch.no_grad():
        # Print optimisation step
        theta_history12.append(theta21.clone())       
print(f"Estimated parameters Energy: {theta21.detach().numpy()}")
print(f"True parameters Energy: {theta_true.numpy()}")
# Out:
# Estimated parameters Energy: [0.51105565 1.0135404  1.9902246 ]
# True parameters Energy: [0.5 1.  2. ]

# %%
import torch
import torch.optim as optim
import torch.nn.functional as F


SR_beta = 1 ## choose beta


# Generate values for the observed (y) and the predicted values given by the linear regression
torch.manual_seed(0)
X = torch.randn(100, 2)
intercept = torch.ones(100, 1)  # intercept
X = torch.cat((intercept, X), dim=1)  
theta_true = torch.tensor([0.5, 1.0, 2.0])  
y = X @ theta_true + 0.01 * torch.randn(100)

# Initialise parameters to be estimated
theta22 = torch.randn(3, requires_grad=True) 

# Set up the optimiser
optimizer = optim.Adam([theta22], lr=0.1)
theta_history13 = []
# Training loop
for i in range(500):

    y_pred = X @ theta22 + 0.01 * torch.randn(100)

    loss = SR_eval(SR_beta, y.view(-1, 1), y_pred.view(-1, 1))  # Compute loss
    loss.backward()  # Backpropagation
    optimizer.step()  # Update parameters
    optimizer.zero_grad()  # Zero gradients
    with torch.no_grad():
        # Print optimisation step
        theta_history13.append(theta22.clone())       
print(f"Estimated parameters Energy: {theta22.detach().numpy()}")
print(f"True parameters Energy: {theta_true.numpy()}")
# Out:
# Estimated parameters Energy: [0.48561117 0.99244773 2.0106375 ]
# True parameters Energy: [0.5 1.  2. ]

# %%
import torch
import torch.optim as optim
import torch.nn.functional as F


SR_beta = 1.5 ## choose beta


# Generate values for the observed (y) and the predicted values given by the linear regression
torch.manual_seed(0)
X = torch.randn(100, 2)
intercept = torch.ones(100, 1)  # intercept
X = torch.cat((intercept, X), dim=1) 
theta_true = torch.tensor([0.5, 1.0, 2.0])  
y = X @ theta_true + 0.01 * torch.randn(100)

# Initialise parameters to be estimated
theta23 = torch.randn(3, requires_grad=True)  

# Set up the optimizer
optimizer = optim.Adam([theta23], lr=0.1)
theta_history14 = []
# Training loop
for i in range(500):

    y_pred = X @ theta23 + 0.01 * torch.randn(100)

    loss = SR_eval(SR_beta, y.view(-1, 1), y_pred.view(-1, 1))  # Compute loss
    loss.backward()  # Backpropagation
    optimizer.step()  # Update parameters
    optimizer.zero_grad()  # Zero gradients
    with torch.no_grad():
        # Print optimisation step
        theta_history14.append(theta23.clone())       
print(f"Estimated parameters Energy: {theta23.detach().numpy()}")
print(f"True parameters Energy: {theta_true.numpy()}")
# Out:
# Estimated parameters Energy: [0.5068249 1.0039289 2.0014963]
# True parameters Energy: [0.5 1.  2. ]

# %%
import torch
import torch.optim as optim
import torch.nn.functional as F



SR_beta = 1.9 ## choose beta


# Generate values for the observed (y) and the predicted values given by the linear regression
torch.manual_seed(0)
X = torch.randn(100, 2)
intercept = torch.ones(100, 1)  # intercept
X = torch.cat((intercept, X), dim=1)  
theta_true = torch.tensor([0.5, 1.0, 2.0])  
y = X @ theta_true + 0.01 * torch.randn(100)

# Initialise parameters to be estimated
theta24 = torch.randn(3, requires_grad=True)  

# Set up the optimiser
optimizer = optim.Adam([theta24], lr=0.1)
theta_history15 = []
# Training loop
for i in range(500):

    y_pred = X @ theta24 + 0.01 * torch.randn(100)

    loss = SR_eval(SR_beta, y.view(-1, 1), y_pred.view(-1, 1))  # Compute loss
    loss.backward()  # Backpropagation
    optimizer.step()  # Update parameters
    optimizer.zero_grad()  # Zero gradients
    with torch.no_grad():
        # Print optimisation step
        theta_history15.append(theta24.clone())       
print(f"Estimated parameters Energy: {theta24.detach().numpy()}")
print(f"True parameters Energy: {theta_true.numpy()}")
# Out:
# Estimated parameters Energy: [0.5016546 1.0005133 2.001814 ]
# True parameters Energy: [0.5 1.  2. ]

# %% [markdown]
# ## Optimisation

# %%
import matplotlib.pyplot as plt

# Convert lists to tensors
theta_history_tensor11 = torch.stack(theta_history11)
theta_history_tensor12 = torch.stack(theta_history12)
theta_history_tensor13 = torch.stack(theta_history13)
theta_history_tensor14 = torch.stack(theta_history14)
theta_history_tensor15 = torch.stack(theta_history15)



# Create first plot for Theta 0
plt.figure()
plt.plot(theta_history_tensor11[:, 0].numpy(), label='Beta = 0.1')
plt.plot(theta_history_tensor12[:, 0].numpy(), label='Beta = 0.5')
plt.plot(theta_history_tensor13[:, 0].numpy(), label='Beta = 1.0')
plt.plot(theta_history_tensor14[:, 0].numpy(), label='Beta = 1.5')
plt.plot(theta_history_tensor15[:, 0].numpy(), label='Beta = 1.9')
plt.title('Theta 0 History')
plt.xlabel('Iteration')
plt.ylabel('Theta 0')
plt.legend()
plt.grid(True)

# Show the first plot
plt.tight_layout()
plt.show()

# Create second plot for Theta 1
plt.figure()
plt.plot(theta_history_tensor11[:, 1].numpy(), label='Beta = 0.1')
plt.plot(theta_history_tensor12[:, 1].numpy(), label='Beta = 0.5')
plt.plot(theta_history_tensor13[:, 1].numpy(), label='Beta = 1.0')
plt.plot(theta_history_tensor14[:, 1].numpy(), label='Beta = 1.5')
plt.plot(theta_history_tensor15[:, 1].numpy(), label='Beta = 1.9')
plt.title('Theta 1 History')
plt.xlabel('Iteration')
plt.ylabel('Theta 1')
plt.legend()
plt.grid(True)

# Show the second plot
plt.tight_layout()
plt.show()


# Create third plot for Theta 2
plt.figure()
plt.plot(theta_history_tensor11[:, 2].numpy(), label='Beta = 0.1')
plt.plot(theta_history_tensor12[:, 2].numpy(), label='Beta = 0.5')
plt.plot(theta_history_tensor13[:, 2].numpy(), label='Beta = 1.0')
plt.plot(theta_history_tensor14[:, 2].numpy(), label='Beta = 1.5')
plt.plot(theta_history_tensor15[:, 2].numpy(), label='Beta = 1.9')
plt.title('Theta 2 History')
plt.xlabel('Iteration')
plt.ylabel('Theta 2')
plt.legend()
plt.grid(True)

# Show the third plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Grid Search

# %%
import torch
import numpy as np
import torch.nn as nn
import matplotlib.pyplot as plt


# Generate values for the observed (y) and the predicted values given by the linear regression
torch.manual_seed(0)
X = torch.randn(100, 2)
intercept = torch.ones(100, 1)  # intercept
X = torch.cat((intercept, X), dim=1) 
theta_true = torch.tensor([0.5, 1.0, 2.0])  
y = X @ theta_true + 0.01 * torch.randn(100)

# Create a range of theta values
theta_values = torch.linspace(-3, 3, 100)

# Compute energy scores for each theta value
energy_scores_first_param = []
energy_scores_second_param = []
energy_scores_third_param = []
energy_scores_first_param1 = []
energy_scores_second_param1 = []
energy_scores_third_param1 = []
energy_scores_first_param2 = []
energy_scores_second_param2 = []
energy_scores_third_param2 = []
energy_scores_first_param3 = []
energy_scores_second_param3 = []
energy_scores_third_param3 = []
energy_scores_first_param4 = []
energy_scores_second_param4 = []
energy_scores_third_param4 = []


for theta in theta_values:
    y_pred_first_param = X @ torch.tensor([theta, theta_true[1], theta_true[2]]).reshape(3, 1) + 0.01 * torch.randn(100, 1)
    y_pred_second_param = X @ torch.tensor([theta_true[0], theta, theta_true[2]]).reshape(3, 1) + 0.01 * torch.randn(100, 1)
    y_pred_third_param = X @ torch.tensor([theta_true[0], theta_true[1], theta]).reshape(3, 1) + 0.01 * torch.randn(100, 1)

    
    energy_scores_first_param.append(SR_eval(0.1, [y], [y_pred_first_param]))
    energy_scores_second_param.append(SR_eval(0.1, [y], [y_pred_second_param]))
    energy_scores_third_param.append(SR_eval(0.1, [y], [y_pred_third_param]))

    
    energy_scores_first_param1.append(SR_eval(0.1, [y], [y_pred_first_param]))
    energy_scores_second_param1.append(SR_eval(0.1, [y], [y_pred_second_param]))
    energy_scores_third_param1.append(SR_eval(0.1, [y], [y_pred_third_param]))

    
    energy_scores_first_param2.append(SR_eval(0.1, [y], [y_pred_first_param]))
    energy_scores_second_param2.append(SR_eval(0.1, [y], [y_pred_second_param]))
    energy_scores_third_param2.append(SR_eval(0.1, [y], [y_pred_third_param]))

    
    energy_scores_first_param3.append(SR_eval(0.1, [y], [y_pred_first_param]))
    energy_scores_second_param3.append(SR_eval(0.1, [y], [y_pred_second_param]))
    energy_scores_third_param3.append(SR_eval(0.1, [y], [y_pred_third_param]))

    
    energy_scores_first_param4.append(SR_eval(0.1, [y], [y_pred_first_param]))
    energy_scores_second_param4.append(SR_eval(0.1, [y], [y_pred_second_param]))
    energy_scores_third_param4.append(SR_eval(0.1, [y], [y_pred_third_param]))

# Create plots for the first parameter
plt.figure(figsize=(10, 8))

plt.plot(theta_values.numpy(), energy_scores_first_param, label='First Parameter (Beta = 0.1)')
plt.plot(theta_values.numpy(), energy_scores_first_param1, label='First Parameter (Beta = 0.5)')
plt.plot(theta_values.numpy(), energy_scores_first_param2, label='First Parameter (Beta = 1.0)')
plt.plot(theta_values.numpy(), energy_scores_first_param3, label='First Parameter (Beta = 1.5)')
plt.plot(theta_values.numpy(), energy_scores_first_param4, label='First Parameter (Beta = 1.9)')


plt.xlabel('Theta 0')
plt.ylabel('Energy Score')
plt.title('Energy Score for Different Theta Values (First Parameter)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# Create plots for the second parameter

plt.figure(figsize=(10, 8))

plt.plot(theta_values.numpy(), energy_scores_second_param, label='Second Parameter (Beta = 0.1)')
plt.plot(theta_values.numpy(), energy_scores_second_param1, label='Second Parameter (Beta = 0.5)')
plt.plot(theta_values.numpy(), energy_scores_second_param2, label='Second Parameter (Beta = 1.0)')
plt.plot(theta_values.numpy(), energy_scores_second_param3, label='Second Parameter (Beta = 1.5)')
plt.plot(theta_values.numpy(), energy_scores_second_param4, label='Second Parameter (Beta = 1.9)')
plt.xlabel('Theta 1')
plt.ylabel('Energy Score')
plt.title('Energy Score for Different Theta Values (Second Parameter)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()


# Create plots for the third parameter
plt.figure(figsize=(10, 8))

plt.plot(theta_values.numpy(), energy_scores_third_param, label='Third Parameter (Beta = 0.1)')
plt.plot(theta_values.numpy(), energy_scores_third_param1, label='Third Parameter (Beta = 0.5)')
plt.plot(theta_values.numpy(), energy_scores_third_param2, label='Third Parameter (Beta = 1.0)')
plt.plot(theta_values.numpy(), energy_scores_third_param3, label='Third Parameter (Beta = 1.5)')
plt.plot(theta_values.numpy(), energy_scores_third_param4, label='Third Parameter (Beta = 1.9)')


plt.xlabel('Theta 2')
plt.ylabel('Energy Score')
plt.title('Energy Score for Different Theta Values (Third Parameter)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
